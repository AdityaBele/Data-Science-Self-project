# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
import pandas as pd

# %%
con=pymysql.connect(host='localhost',user='root',password='Aditya@4321',db='payroll')

# %%
con

# %%
data=pd.read_sql('select* from Registration',con)
# Out:
# /Users/adityabele703/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
data
# Out:
#    id empname      mobile salary
# 0   1  aditya  7098557765  25000

# %%
import matplotlib.pyplot as plt

# %%
data.head()
# Out:
#    id empname      mobile salary
# 0   1  aditya  7098557765  25000

# %%
x=data['empname']
y=data['salary']

# %%
plt.plot(x,y)
plt.show()

# %%
plt.hist(data['salary'],bins=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(9,9))
data['salary'].value_counts().plot.pie(autopct= '%1.1f%%')

plt.show()
