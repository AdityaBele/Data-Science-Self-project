# %% [markdown]
# # Logical Regression
#    Handling logical regression of "Titanic Dataset" in logical manners and applying Statistic and Algorithm to find and solve the missing value's

# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('Titanic.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 1: Showing Null Value

# %%
sns.heatmap(train.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2 : Researching and Filling
#
#     Researching the DataFrame and applying some algorithms and ploting to understand and solve the missing value       with perfect numbers

# %%
sns.countplot(x='Survived',data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### 0 = 'Dead'
# ### 1 = 'Survived' or 'Alive'

# %%
sns.countplot(x='Survived',hue='Sex',data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### Passenger wise distribution
# #### 1 = 'First Class'
# #### 2 = 'Secound Class'
# #### 3 = 'Low Class'

# %%
sns.countplot(x='Survived',hue='Pclass',data=train)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.distplot(train['Age'].dropna(),kde=False,color='darkred',bins=30)
plt.grid()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='Pclass',y='Age',data=train)
plt.grid()

# %% [markdown]
# ## 3 : Function use to find missing Age Value
#
#     By applying Function model and predection from boxplot.

# %%
def ipmute_age(cols):
    Age = cols[0]
    Pclass= cols[1]
    
    if pd.isnull(Age):
        
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 28
        else:
            return 23
    else:
        return Age

# %% [markdown]
# Now Apply the Function

# %%
train['Age']=train[['Age','Pclass']].apply(ipmute_age,axis=1)

# %% [markdown]
# ## 4 : Data Fitting
#        Fitting missing value with not almost accurate but in the form to analyse with missing any data

# %%
sns.heatmap(train.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This is how Data Cleaning and Handling is Done
# # Thank You
